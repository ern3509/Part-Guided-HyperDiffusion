# %%
from google.colab import drive
import os
drive_path = '/content/gdrive/Othercomputers/Mein Mac/Part-Guided-HyperDiffusion/'


drive.mount('/content/gdrive', force_remount=True)

os.chdir(drive_path)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ###*Downloads*

# %%
#Core ML Tools
# !pip install torch torchvision torchaudio
# !pip install numpy scipy matplotlib scikit-learn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 43.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 21.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 16.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 61.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
#Visualisation and logging
# !pip install tqdm einops wandb torchmetrics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 963.5/963.5 kB 15.9 MB/s eta 0:00:00
# ...

# %%
#Dataset and IO Utilities
# !pip install trimesh pyrender sk-video plyfile
# !pip install hydra-core --upgrade
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 29.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 708.8/708.8 kB 29.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 51.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 64.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 984.0/984.0 kB 46.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 46.1 MB/s eta 0:00:00
# ...
#   Created wheel for PyOpenGL: filename=PyOpenGL-3.1.0-py3-none-any.whl size=1745193 sha256=ff4162ed9580a9851417967516c08341d9d8d1cb55e07f31f683f66a7b80de00
#   Stored in directory: /root/.cache/pip/wheels/2f/37/f5/f88cd3dddf75bc3ce608e44bf8a79078c408bf1f351a50818e
# Successfully built PyOpenGL
# ...
#   Attempting uninstall: PyOpenGL
#     Found existing installation: PyOpenGL 3.1.9
# ...

# %%
#Neural Field & Diffusion Tools
# !pip install pytorch-lightning==1.9.4
# !pip install torch-fidelity
# !pip install libigl==2.4.1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 827.8/827.8 kB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.4/14.4 MB 32.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# ##Train/Test

# %%
# !pip install tensorflow==2.16.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 589.8/589.8 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 58.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 65.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 19.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 75.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.5
#     Uninstalling protobuf-5.29.5:
#       Successfully uninstalled protobuf-5.29.5
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.18.0
#     Uninstalling tensorboard-2.18.0:
#       Successfully uninstalled tensorboard-2.18.0
# ...

# %%
# !pip install open3d
# !pip install rtree
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.7/447.7 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 70.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 57.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 50.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.10
#     Uninstalling widgetsnbextension-3.6.10:
#       Successfully uninstalled widgetsnbextension-3.6.10
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 541.1/541.1 kB 7.4 MB/s eta 0:00:00
# ...

# %%
# !python siren/experiment_scripts/part_datapoints.py
# Out:
# Starting preprocessing...
# Shapes:   0% 0/221 [00:00<?, ?it/s]❌ Missing 'objs/' folder for 963, skipping.
# ❌ Missing 'objs/' folder for 1086, skipping.
# ❌ Missing 'objs/' folder for 1156, skipping.
# ❌ Missing 'objs/' folder for 944, skipping.
# ❌ Missing 'objs/' folder for 1182, skipping.
# ❌ Missing 'objs/' folder for 1162, skipping.
# ❌ Missing 'objs/' folder for 1117, skipping.
# ❌ Missing 'objs/' folder for 442, skipping.
# ❌ Missing 'objs/' folder for 1227, skipping.
# ❌ Missing 'objs/' folder for 830, skipping.
# ❌ Missing 'objs/' folder for 873, skipping.
# ❌ Missing 'objs/' folder for 872, skipping.
# ❌ Missing 'objs/' folder for 1027, skipping.
# ❌ Missing 'objs/' folder for 1222, skipping.
# ❌ Missing 'objs/' folder for 874, skipping.
# ❌ Missing 'objs/' folder for 1110, skipping.
# ❌ Missing 'objs/' folder for 933, skipping.
# ❌ Missing 'objs/' folder for 1273, skipping.
# ❌ Missing 'objs/' folder for 904, skipping.
# ❌ Missing 'objs/' folder for 1256, skipping.
# ...

# %%
# !python siren/experiment_scripts/parts_to_ply.py
# Out:
# /content/gdrive/Othercomputers/Mein Mac/Part-Guided-HyperDiffusion/siren/experiment_scripts/parts_to_ply.py:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   color_map = plt.cm.get_cmap("tab20", len(unique_labels))  # good for categorical
# ✅ Saved: ./data/knife_colored_ply/1193.ply
# ✅ Saved: ./data/knife_colored_ply/1167.ply

# %%
#!python siren/experiment_scripts/train_sdf.py --config-name=overfit_knife strategy=save_pc

# %%
#!python experiment_PGHD/main.py --config-name=overfit_knife strategy=save_pc

# %%
# !python siren/experiment_scripts/reworking_the_folders.py
# Out:
# ✅ Fixed: ./data/knife_preprocessed_split/train_split.lst

# %%
# !python siren/experiment_scripts/train_sdf.py --config-name=overfit_knife
# Out:
# /usr/local/lib/python3.11/dist-packages/torchmetrics/utilities/prints.py:43: UserWarning: Metric `FrechetInceptionDistance` will save all extracted features in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# 2025-07-10 19:09:25.970774: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-10 19:09:27.888808: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: adonie27ndjongang (adonie27ndjongang-technical-university-of-munich) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.21.0
# ...

# %%
# !python main.py --config-name=train_plane epochs=1 #mlp_config.hidden_neurons="[32, 32, 32]"
#!python main.py --config-name=train_plane mode=test best_model_save_path=plane-001.ckpt
# Out:
# /usr/local/lib/python3.11/dist-packages/torchmetrics/utilities/prints.py:43: UserWarning: Metric `FrechetInceptionDistance` will save all extracted features in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# Downloading: "https://github.com/toshas/torch-fidelity/releases/download/v0.2.0/weights-inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/weights-inception-2015-12-05-6726825d.pth
# 100% 91.2M/91.2M [00:00<00:00, 285MB/s]
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# ...

# %%
# !python --version
# Out:
# Python 3.11.12

# %%
import torch
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.18.0
